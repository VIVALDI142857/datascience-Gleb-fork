# %%
"""Pyetoprosto."""
# Out:
# 'Pyetoprosto.'

# %%
import pandas as pd

# %% [markdown]
# 1 глава
#
#
#
# Data Science - это наука об изучении данных для того, чтобы дан­ ные обрели смысл и дали нам полезную информацию. Эта наука не касается какой­ то конкретной предметной области, а являет собой сочетание различных дисцип­ лин, связанных с анализом данных и выдаче «умных» результатов и решений, основанных на этих данных.
#
# Исходный код - это то, что пишут программисты на всех языках программирова­ния. Это те самые указания, которые мы даем компьютеру, написанные неформа­тированным текстом. В таком тесте нет таких средств форматирования, как выде­ ление полужирным, курсив или подчеркивание.
#
# Компилятор - программа, преобразующая исходный код в машинный
#
# В компьютерном программировании интерпретатор - это компьютерная про­грамма, которая непосредственно выполняет инструкции, написанные на языке программирования, без предварительной компиляции в программу на машинном языке.
#
# Основные различия между компиляторами и интерпретаторами:
# 1 . И компиляторы, и интерпретаторы преобразуют исходный код (текстовые фай­ лы) в машинный язык. Основное их отличие состоит в том, что компилятор генерирует автономную программу, написанную на машинном коде, а система интерпретатора выполняет действия, описанные программой высокого уровня.
# 2. После компиляции программы ее исходный код для запуска больше не требует­ ся. У интерпретируемых программ исходный код требуется для запуска про­ граммы каждый раз.
# 3. Обычно интерпретируемые программы работают медленнее, чем компилириуемые
#
#
# 2 глава
#
#
#
# Python - это бесплатный интерпретируемый высокоуровневый язык программирования общего назначения с открытым исходным ходом.
# Выпущен Гвидо ва Россумом в 1991
#
#
# Философия Python
# ♦ Красивое лучше, чем уродливое.
# ♦ Явное лучше, чем неявное.
# ♦ Простое лучше, чем сложное.
# ♦ Сложное лучше, чем запутанное.
#  ♦ Читаемость имеет значение.
#
#
# По определению интерпретатор - это разновидность компьютерной программы, которая непосредственно выполняет инструкции, написанные на каком-либо языке программирования или языке сценариев. Под непосредственным выполнением подразумевается, что предварительная компиляция кода в программу на машинном языке не требуется.
#
# Anaconda - дистрибутив с множеством инструментов для анализа данных и не только.
#
#
# 3 глава
#
# Строки можно объединять (склеивать) с помощью оператора + и повторять с по­ мощью оператора *. Запомнить это просто. Оператор + складывает, а оператор * умножает.
# Строки можно индексировать (обращаться к элементам строки по индексу), при этом первый символ имеет индекс О. Отдельного типа для данных символов не существует, т. к. символ - это просто строка длиной в один символ.
# Помимо индексирования строк также поддерживаются срезы. Если индексирование используется для извлечения отдельных символов, то срез возвращает подстроку.
# In [28] : word[0:2] # с позиции О (включительно) до 2 (не включая его)
# У срезов есть полезные значения по умолчанию для индексов. Опущенный первый индекс по умолчанию равен нулю, опущенный второй индекс по умолчанию равен длине строки.
#
# Чтобы лучше понять приведенные выше понятия, рассмотрим примеры.
# # перенос выражения на новую строку с использованием \
# s=1+2+3+\ 4+5+6+\
# 7+8+9
# # перенос выражения на новую строку с использованием () n = (1 * 2 * 3 + 7
# + 8 + 9)
# # перенос выражения на новую строку с использованием [] footballer = ['МESSI',
# ' NEYМAR ' ,
# ' SUAREZ ' ]
# # перенос выражения на новую строку с использованием { } х={1+2+3+4+5+6+}
#  любого языка программирования - это возможность работать с переменными. Переменная - это некоторое имя, свя­ занное со значением. Переменная лишь ссылается на зна­ чение, которое ей присвоено, но не тождественна ему. Когда переменной присваи­вается новое значение старое становится недействительным.
#  Выражение- это совокупность значений, переменных и операторов.
#  Аргументы - это все, что мы передаем в функцию. Например, в функцию print ( ) мы передавали строку или переменную - это и есть аргументы.
#  Семантические или логические ошибки- это проблемы с самим построением вашей программы.
#
#
#  Глава 4
#
#
#  Когда мы вводим переменную вида х = 38, то в этой записи х - это имя перемен­ной, (=) - это оператор присваивания, а 38 - это присвоенное значение.
# Здесь знак (=) не означает «равно». Он означает «при­своить». В Python «равно» записывается как ==.
# В Python все данные становятся объектами. Объекты могут быть либо встроенны­ми, которые есть в Python изначально, либо мы создаем их сами с помощью классов Python.
# Классификация объектов
# Объекты делятся по типу данных на:
# ♦ встроенные;
# ♦ пользовательские.
# Типы данных также бывают:
# ♦ изменяемые;
# ♦ неизменяемые.
#
# Объекты- это абстракция данных Python. Любые данные в программе Python представлены либо объектами, либо отношениями между объектами.
# Объект можно представить как сочетание трех вещей:
# ♦ идентификатор;
# ♦ тип данных;
# ♦ значение.
# У каждого объекта есть идентификатор, тип и значение.
#
# Тип объекта определяет операции, которые объект поддерживает, а также возмож­ные значения для объектов этого типа. Функция type ( ) возвращает тип объекта. Как и идентификатор, тип объекта также нельзя изменять.
#
# объекты, значение которых может меняться, называются изменяемыми, а объекты, значение которых после создания остается постонным, называются неизменяемыми.
# Объекты, содержащие ссылки на другие объекты называются контейнерами (кортежи, списки, словари)
#
# Иерархия типов
# None
# У этого типа данных одно-единственное значение. И есть только один объект с таким значением. Доступ к этому объекту осуществляется через встроенное имя None. Он используется для обозначения отсутствия значения, например воз­ вращается из функций, которые ничего явно не возвращают. В логическом смысле эквивалентен False.
# ♦ Notimplemented
# У этого типа одно-единственное значение. И это единственный объект с таким значением. Доступ к этому объекту осуществляется через встроенное имя Notimplemented. Числовые методы и методы сравнения должны возвращать этот объект, если они не реализуют операцию для предоставленных операндов. В ло­гическом смысле эквивалентен True.
# ♦ Ellipsis
# У этого типа одно-единственное значение. И это единственный объект с таким значением. Доступ к этому объекту осуществляется через литерал . . . или встро­ енное имя Ellipsis. В логическом смысле эквивалентен True.
# Комплексные числа (complex)
# Комплексные числа представляются как пара чисел с плавающей точкой двой­ ной точности машинного уровня. Ограничения те же, что и у чисел с плавающей запятой. Действительную и мнимую части комплексного числа z можно полу­ чить с помощью атрибутов z.real и z.imag.
# Неизменяемые последовательности не могут быть изменены после создания. Если объект содержит ссылки на другие объекты, то эти другие объекты могут изме­ няться, но коллекция объектов, на которые ссылается эта неизменяемая последо­ вальность, измениться не может.
# Байтовыестроки(Ьytes)
# Объект типа bytes - это неизменяемый массив. Его элементы представляют со­ бой 8-битные числа х, такие что о <= х < 256. Для создания байтовых строк мож­ но использовать байтовые литералы (например, Ь'аЬс') или встроенный конст­ руктор bytes ( ) . Кроме того, байтовые строки можно декодировать в строки с по­ мощью метода decode ( ) .
#
#
#
# Операторы идентификации проверяют идентичность двух объектов.
# • is
# Если если х - это тот же объект, что и у, выраж
#
# • is not
# Если х не является тем же объектом, что и у, выражение возвращает True.
# В противном случае возвращается False.
#
# ♦ Операторы вхождении проверяют, является ли данный объект элементом дан­ ной коллекции. Под «коллекцией» понимается последовательность или структу­ ра данных, например строка, список, кортеж и т. д.
# • in
# Если х является элементом коллекции у, то возвращается тrue, в противном случае возвращается False.
# • notin
# Если х не является элементом коллекции у, возвращается True, в противном случае возвращается False.
#
#
# Динамическая типизация
# В Python значение, на которое указывает переменная, имеет определенный тип данных, но сама переменная не имеет строгого типа. Вы можете повторно исполь­ зовать одну и ту же переменную, передавая ей ссьmку на объект уже другого типа. Переменные можно считать «ярлыками», связанными с объектами.
#
# Строгая типизация
# Хотя Python позволяет гибко обходиться с типами данных, вам тем не менее нужно знать, объекты каких типов вы используете. Для некоторых операций требуются аргументы определенного типа. Нельзя производить например арифметические операции с объектами разных типов данных.

# %%
letter1 = "r"
letter2 = "a"
concat = letter1 + letter2
repetition = letter1 * 7

# %%
indexes = {
    "P": [0, -6],
    "y": [1, -5],
    "t": [2, -4],
    "h": [3, -3],
    "o": [4, -2],
    "n": [5, -1],
}
python_index = pd.DataFrame(indexes)
python_index
# Out:
#    P  y  t  h  o  n
# 0  0  1  2  3  4  5
# 1 -6 -5 -4 -3 -2 -1
